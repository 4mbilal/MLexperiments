# %% [markdown]
# # Training a regression model using TensorFlow
# > This is a basic tutorial for training a regression model using Tensorflow. It covers:
#
# 1- Regression to approximate Sine function using Multilayer Perceptron (MLP)
#
# 2- Conversion of the Tensorflow model to Tensorflow Lite (quantization)
#
# Inspired from:
# https://github.com/tensorflow/tflite-micro/tree/main/tensorflow/lite/micro/examples/hello_world/

# %%
#from google.colab import drive
#drive.mount('/content/gdrive')

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math

plt.rcParams['figure.figsize'] = (32, 20)
plt.rcParams['text.usetex'] = True
plt.rc('font', size=15)
plt.style.use('classic')

# %% [markdown]
# ### Hello world
# In this example, our ML regression hypothesis will approximate the sine function.
#
# $$ \tilde{h}(x) = \sin(x) $$

# %%
# Seed the RNG to get the same random numbers everytime
np.random.seed(1) # numpy seed
tf.random.set_seed(1) # tensorflow seed

# %%
print('Numpy: {}'.format(np.__version__))
print('Tensorflow: {}'.format(tf.__version__))
# Out:
# Numpy: 1.26.4
# Tensorflow: 2.10.0

# %% [markdown]
# Generate artificial training data through known function i.e. sine

# %%
# Generate uniformly distributed RVs in the range [0 2*pi].
#X = np.random.uniform(low=0, high=2*math.pi, size=10000).astype(np.float32)

# Generate uniformly distributed RVs in the range [-pi pi]
#This dataset give a better output! Maybe because data is centered around zero?
X = np.random.uniform(low=-math.pi, high=math.pi, size=10000).astype(np.float32)

# Shuffle to break order
np.random.shuffle(X)

# Calculate the labels
y = np.sin(X).astype(np.float32)

# Add a little noise to make it realistic
y += 0.1 * np.random.randn(*y.shape)

# Plot our data
plt.plot(X, y, 'b.')
plt.grid()
plt.show()

# %% [markdown]
# Split the data as follows:
#
# - Train data: 60%
# - Validation data: 20%
# - Test data: 20%

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=1)

# Plot using different colors:
plt.plot(X_train, y_train, 'b.', label="Train")
plt.plot(X_val, y_val, 'y.', label="Validate")
plt.plot(X_test, y_test, 'r.', label="Test")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Our regression model will have three layers: input, hidden and output. The hidden layer has 16 neurons with Relu activation function. To implement this, we use the sequential model in tensorflow-keras.
# We will use Adam optimizer with a learning rate of 1.5. Mean Squared Error (MSE) will be the loss and Mean Absolute Error (MAE) will also be plotted to see the training progress.

# %%
model1 = tf.keras.Sequential(name='sine_mlp')
model1.add(tf.keras.layers.Dense(64, activation='relu', input_shape=(1, )))
#model1.add(tf.keras.layers.Dense(16, activation='sigmoid', input_shape=(1, )))
model1.add(tf.keras.layers.Dense(1))
#No activation layer applied at the output i.e. linear

model1.summary()
# Out:
# Model: "sine_mlp"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 64)                128
#
#  dense_6 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________

# %%
#model.compile(optimizer='adam', loss='mse', metrics=['accuracy', 'mae'])
optimizer = tf.keras.optimizers.Adam(lr=10)
model1.compile(optimizer=optimizer, loss='mse', metrics=['accuracy', 'mae'])
# Out:
# c:\Users\mbilal\.conda\envs\tf-gpu\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %% [markdown]
# Let's train it with a batch size of 15 for 50 epochs.

# %%
history = model1.fit(X_train, y_train, epochs=100, batch_size=600, validation_data=(X_val, y_val), verbose=True)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 0s 16ms/step - loss: 10181599.0000 - accuracy: 0.0000e+00 - mae: 1611.8153 - val_loss: 518156.5625 - val_accuracy: 0.0000e+00 - val_mae: 315.8652
# Epoch 2/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1051911.1250 - accuracy: 0.0000e+00 - mae: 473.5786 - val_loss: 169226.3594 - val_accuracy: 0.0000e+00 - val_mae: 180.1749
# Epoch 3/100
# 10/10 [==============================] - 0s 6ms/step - loss: 43892.8555 - accuracy: 0.0000e+00 - mae: 83.7228 - val_loss: 1777.7349 - val_accuracy: 0.0000e+00 - val_mae: 42.0386
# Epoch 4/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1617.0939 - accuracy: 0.0000e+00 - mae: 40.1690 - val_loss: 1346.3405 - val_accuracy: 0.0000e+00 - val_mae: 36.6855
# Epoch 5/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1028.3894 - accuracy: 0.0000e+00 - mae: 31.9018 - val_loss: 655.7587 - val_accuracy: 0.0000e+00 - val_mae: 25.5978
# Epoch 6/100
# 10/10 [==============================] - 0s 6ms/step - loss: 423.9618 - accuracy: 0.0000e+00 - mae: 20.3081 - val_loss: 202.6435 - val_accuracy: 0.0000e+00 - val_mae: 14.2173
# Epoch 7/100
# 10/10 [==============================] - 0s 6ms/step - loss: 107.7187 - accuracy: 0.0000e+00 - mae: 10.0401 - val_loss: 32.2128 - val_accuracy: 0.0000e+00 - val_mae: 5.6303
# Epoch 8/100
# 10/10 [==============================] - 0s 7ms/step - loss: 12.1439 - accuracy: 0.0000e+00 - mae: 3.0656 - val_loss: 0.8802 - val_accuracy: 0.0000e+00 - val_mae: 0.7683
# Epoch 9/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.2027 - accuracy: 0.0000e+00 - mae: 0.8965 - val_loss: 2.6233 - val_accuracy: 0.0000e+00 - val_mae: 1.4529
# Epoch 10/100
# 10/10 [==============================] - 0s 5ms/step - loss: 3.3478 - accuracy: 0.0000e+00 - mae: 1.6787 - val_loss: 3.3026 - val_accuracy: 0.0000e+00 - val_mae: 1.6704
# Epoch 11/100
# 10/10 [==============================] - 0s 5ms/step - loss: 2.6960 - accuracy: 0.0000e+00 - mae: 1.4673 - val_loss: 1.7244 - val_accuracy: 0.0000e+00 - val_mae: 1.1018
# Epoch 12/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2196 - accuracy: 0.0000e+00 - mae: 0.8934 - val_loss: 0.7085 - val_accuracy: 0.0000e+00 - val_mae: 0.7020
# Epoch 13/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5967 - accuracy: 0.0000e+00 - mae: 0.6712 - val_loss: 0.5125 - val_accuracy: 0.0000e+00 - val_mae: 0.6407
# Epoch 14/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5259 - accuracy: 0.0000e+00 - mae: 0.6497 - val_loss: 0.5388 - val_accuracy: 0.0000e+00 - val_mae: 0.6504
# Epoch 15/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5411 - accuracy: 0.0000e+00 - mae: 0.6540 - val_loss: 0.5385 - val_accuracy: 0.0000e+00 - val_mae: 0.6503
# Epoch 16/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5316 - accuracy: 0.0000e+00 - mae: 0.6511 - val_loss: 0.5220 - val_accuracy: 0.0000e+00 - val_mae: 0.6446
# Epoch 17/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5215 - accuracy: 0.0000e+00 - mae: 0.6482 - val_loss: 0.5139 - val_accuracy: 0.0000e+00 - val_mae: 0.6414
# Epoch 18/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5195 - accuracy: 0.0000e+00 - mae: 0.6474 - val_loss: 0.5125 - val_accuracy: 0.0000e+00 - val_mae: 0.6407
# Epoch 19/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5194 - accuracy: 0.0000e+00 - mae: 0.6474 - val_loss: 0.5125 - val_accuracy: 0.0000e+00 - val_mae: 0.6407
# Epoch 20/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5193 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5126 - val_accuracy: 0.0000e+00 - val_mae: 0.6408
# Epoch 21/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5129 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 22/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 23/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5131 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 24/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5129 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 25/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5131 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 26/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 27/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 28/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5128 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 29/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5129 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 30/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 31/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 32/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 33/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 34/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5129 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 35/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 36/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5193 - accuracy: 0.0000e+00 - mae: 0.6474 - val_loss: 0.5128 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 37/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 38/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5132 - val_accuracy: 0.0000e+00 - val_mae: 0.6411
# Epoch 39/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5193 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5128 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 40/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 41/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 42/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5129 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 43/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 44/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5131 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 45/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5129 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 46/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5129 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 47/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5193 - accuracy: 0.0000e+00 - mae: 0.6474 - val_loss: 0.5131 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 48/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5129 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 49/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5128 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 50/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 51/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5193 - accuracy: 0.0000e+00 - mae: 0.6474 - val_loss: 0.5132 - val_accuracy: 0.0000e+00 - val_mae: 0.6411
# Epoch 52/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5129 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 53/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5127 - val_accuracy: 0.0000e+00 - val_mae: 0.6408
# Epoch 54/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5129 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 55/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5131 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 56/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5132 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 57/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5193 - accuracy: 0.0000e+00 - mae: 0.6474 - val_loss: 0.5129 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 58/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 59/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 60/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5132 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 61/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5128 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 62/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5128 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 63/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6474 - val_loss: 0.5131 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 64/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 65/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5129 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 66/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 67/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 68/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5129 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 69/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 70/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5131 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 71/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5194 - accuracy: 0.0000e+00 - mae: 0.6474 - val_loss: 0.5127 - val_accuracy: 0.0000e+00 - val_mae: 0.6408
# Epoch 72/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5131 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 73/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5131 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 74/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5128 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 75/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 76/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5128 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 77/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5131 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 78/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5128 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 79/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5129 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 80/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 81/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5131 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 82/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5129 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 83/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5127 - val_accuracy: 0.0000e+00 - val_mae: 0.6408
# Epoch 84/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 85/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5129 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 86/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5131 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 87/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5129 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 88/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 89/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5133 - val_accuracy: 0.0000e+00 - val_mae: 0.6411
# Epoch 90/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5129 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 91/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5128 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 92/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5194 - accuracy: 0.0000e+00 - mae: 0.6474 - val_loss: 0.5133 - val_accuracy: 0.0000e+00 - val_mae: 0.6411
# Epoch 93/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5129 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 94/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5128 - val_accuracy: 0.0000e+00 - val_mae: 0.6408
# Epoch 95/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5193 - accuracy: 0.0000e+00 - mae: 0.6474 - val_loss: 0.5131 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 96/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5128 - val_accuracy: 0.0000e+00 - val_mae: 0.6409
# Epoch 97/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 98/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5130 - val_accuracy: 0.0000e+00 - val_mae: 0.6410
# Epoch 99/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5193 - accuracy: 0.0000e+00 - mae: 0.6474 - val_loss: 0.5127 - val_accuracy: 0.0000e+00 - val_mae: 0.6408
# Epoch 100/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5192 - accuracy: 0.0000e+00 - mae: 0.6473 - val_loss: 0.5129 - val_accuracy: 0.0000e+00 - val_mae: 0.6409

# %%
# Plot the training and validation losses.
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'g.', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Evaluate the model on Test set
loss = model1.evaluate(X_test, y_test)
predictions = model1.predict(X_test)
# print(predictions)

# Visualize the predictions against labels
plt.clf()
plt.title('Comparison of predictions with actual labels')
plt.plot(X_test, y_test, 'b.', label='Actual Labels (Ground Truth)')
plt.plot(X_test, predictions, 'r.', label='Predictions')
plt.legend()
plt.show()
# Out:
# 63/63 [==============================] - 0s 3ms/step - loss: 0.5053 - accuracy: 0.0000e+00 - mae: 0.6330
# 63/63 [==============================] - 0s 1ms/step
# [[-0.00613022]
#  [-0.00613022]
#  [-0.00613022]
#  ...
#  [-0.00613022]
#  [-0.00613022]
#  [-0.00613022]]

# %% [markdown]
# Let's try a model with more hidden layers (deep) but with fewer neurons per layer

# %%
model2 = tf.keras.Sequential(name='sine_mlp_deep')

# Input to the first layer is a scalar which feeds the next hidden layer with 4 neurons
model2.add(tf.keras.layers.Dense(12, activation='relu', input_shape=(1,)))

# The second layer has 4 neurons and will learn more complex features than one hidden layer alone
model2.add(tf.keras.layers.Dense(4, activation='relu'))

# Final layer outputs a scalar
model2.add(tf.keras.layers.Dense(1))

# Compile the model and set appropriate training parameters
#optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
optimizer = tf.keras.optimizers.Adam(lr=0.1)
model2.compile(optimizer=optimizer, loss='mse', metrics=['accuracy', 'mae'])

model2.summary()
# Out:
# Model: "sine_mlp_deep"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 12)                24
#
#  dense_3 (Dense)             (None, 4)                 52
#
#  dense_4 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 81
# Trainable params: 81
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model2.fit(X_train, y_train, epochs=50, batch_size=64,
                    validation_data=(X_val, y_val), verbose=True)
# Out:
# Epoch 1/50
# 94/94 [==============================] - 1s 4ms/step - loss: 0.1912 - accuracy: 0.0000e+00 - mae: 0.3243 - val_loss: 0.0437 - val_accuracy: 0.0000e+00 - val_mae: 0.1522
# Epoch 2/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0419 - accuracy: 0.0000e+00 - mae: 0.1481 - val_loss: 0.0446 - val_accuracy: 0.0000e+00 - val_mae: 0.1595
# Epoch 3/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0430 - accuracy: 0.0000e+00 - mae: 0.1520 - val_loss: 0.0409 - val_accuracy: 0.0000e+00 - val_mae: 0.1446
# Epoch 4/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0428 - accuracy: 0.0000e+00 - mae: 0.1512 - val_loss: 0.0440 - val_accuracy: 0.0000e+00 - val_mae: 0.1573
# Epoch 5/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0437 - accuracy: 0.0000e+00 - mae: 0.1541 - val_loss: 0.0414 - val_accuracy: 0.0000e+00 - val_mae: 0.1475
# Epoch 6/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0418 - accuracy: 0.0000e+00 - mae: 0.1475 - val_loss: 0.0408 - val_accuracy: 0.0000e+00 - val_mae: 0.1444
# Epoch 7/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0427 - accuracy: 0.0000e+00 - mae: 0.1513 - val_loss: 0.0473 - val_accuracy: 0.0000e+00 - val_mae: 0.1689
# Epoch 8/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0445 - accuracy: 0.0000e+00 - mae: 0.1564 - val_loss: 0.0420 - val_accuracy: 0.0000e+00 - val_mae: 0.1501
# Epoch 9/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0433 - accuracy: 0.0000e+00 - mae: 0.1533 - val_loss: 0.0424 - val_accuracy: 0.0000e+00 - val_mae: 0.1496
# Epoch 10/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0435 - accuracy: 0.0000e+00 - mae: 0.1523 - val_loss: 0.0431 - val_accuracy: 0.0000e+00 - val_mae: 0.1515
# Epoch 11/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0432 - accuracy: 0.0000e+00 - mae: 0.1525 - val_loss: 0.0406 - val_accuracy: 0.0000e+00 - val_mae: 0.1421
# Epoch 12/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0423 - accuracy: 0.0000e+00 - mae: 0.1490 - val_loss: 0.0432 - val_accuracy: 0.0000e+00 - val_mae: 0.1537
# Epoch 13/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0420 - accuracy: 0.0000e+00 - mae: 0.1484 - val_loss: 0.0400 - val_accuracy: 0.0000e+00 - val_mae: 0.1401
# Epoch 14/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0432 - accuracy: 0.0000e+00 - mae: 0.1526 - val_loss: 0.0483 - val_accuracy: 0.0000e+00 - val_mae: 0.1718
# Epoch 15/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0436 - accuracy: 0.0000e+00 - mae: 0.1535 - val_loss: 0.0400 - val_accuracy: 0.0000e+00 - val_mae: 0.1423
# Epoch 16/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0426 - accuracy: 0.0000e+00 - mae: 0.1511 - val_loss: 0.0436 - val_accuracy: 0.0000e+00 - val_mae: 0.1504
# Epoch 17/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 0.0000e+00 - mae: 0.1494 - val_loss: 0.0401 - val_accuracy: 0.0000e+00 - val_mae: 0.1401
# Epoch 18/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 0.0000e+00 - mae: 0.1489 - val_loss: 0.0414 - val_accuracy: 0.0000e+00 - val_mae: 0.1487
# Epoch 19/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0420 - accuracy: 0.0000e+00 - mae: 0.1483 - val_loss: 0.0478 - val_accuracy: 0.0000e+00 - val_mae: 0.1687
# Epoch 20/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0423 - accuracy: 0.0000e+00 - mae: 0.1492 - val_loss: 0.0416 - val_accuracy: 0.0000e+00 - val_mae: 0.1484
# Epoch 21/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0421 - accuracy: 0.0000e+00 - mae: 0.1479 - val_loss: 0.0406 - val_accuracy: 0.0000e+00 - val_mae: 0.1455
# Epoch 22/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0425 - accuracy: 0.0000e+00 - mae: 0.1498 - val_loss: 0.0442 - val_accuracy: 0.0000e+00 - val_mae: 0.1496
# Epoch 23/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0432 - accuracy: 0.0000e+00 - mae: 0.1508 - val_loss: 0.0442 - val_accuracy: 0.0000e+00 - val_mae: 0.1509
# Epoch 24/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0425 - accuracy: 0.0000e+00 - mae: 0.1502 - val_loss: 0.0412 - val_accuracy: 0.0000e+00 - val_mae: 0.1439
# Epoch 25/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0429 - accuracy: 0.0000e+00 - mae: 0.1505 - val_loss: 0.0407 - val_accuracy: 0.0000e+00 - val_mae: 0.1445
# Epoch 26/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0427 - accuracy: 0.0000e+00 - mae: 0.1501 - val_loss: 0.0404 - val_accuracy: 0.0000e+00 - val_mae: 0.1448
# Epoch 27/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0431 - accuracy: 0.0000e+00 - mae: 0.1518 - val_loss: 0.0422 - val_accuracy: 0.0000e+00 - val_mae: 0.1509
# Epoch 28/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0427 - accuracy: 0.0000e+00 - mae: 0.1495 - val_loss: 0.0399 - val_accuracy: 0.0000e+00 - val_mae: 0.1376
# Epoch 29/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0430 - accuracy: 0.0000e+00 - mae: 0.1513 - val_loss: 0.0403 - val_accuracy: 0.0000e+00 - val_mae: 0.1436
# Epoch 30/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0436 - accuracy: 0.0000e+00 - mae: 0.1526 - val_loss: 0.0411 - val_accuracy: 0.0000e+00 - val_mae: 0.1415
# Epoch 31/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0431 - accuracy: 0.0000e+00 - mae: 0.1521 - val_loss: 0.0433 - val_accuracy: 0.0000e+00 - val_mae: 0.1533
# Epoch 32/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0432 - accuracy: 0.0000e+00 - mae: 0.1512 - val_loss: 0.0404 - val_accuracy: 0.0000e+00 - val_mae: 0.1440
# Epoch 33/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0431 - accuracy: 0.0000e+00 - mae: 0.1518 - val_loss: 0.0422 - val_accuracy: 0.0000e+00 - val_mae: 0.1488
# Epoch 34/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0425 - accuracy: 0.0000e+00 - mae: 0.1502 - val_loss: 0.0446 - val_accuracy: 0.0000e+00 - val_mae: 0.1593
# Epoch 35/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0433 - accuracy: 0.0000e+00 - mae: 0.1529 - val_loss: 0.0449 - val_accuracy: 0.0000e+00 - val_mae: 0.1601
# Epoch 36/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0440 - accuracy: 0.0000e+00 - mae: 0.1536 - val_loss: 0.0407 - val_accuracy: 0.0000e+00 - val_mae: 0.1454
# Epoch 37/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0423 - accuracy: 0.0000e+00 - mae: 0.1492 - val_loss: 0.0468 - val_accuracy: 0.0000e+00 - val_mae: 0.1680
# Epoch 38/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0427 - accuracy: 0.0000e+00 - mae: 0.1504 - val_loss: 0.0422 - val_accuracy: 0.0000e+00 - val_mae: 0.1511
# Epoch 39/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 0.0000e+00 - mae: 0.1490 - val_loss: 0.0453 - val_accuracy: 0.0000e+00 - val_mae: 0.1625
# Epoch 40/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 0.0000e+00 - mae: 0.1497 - val_loss: 0.0401 - val_accuracy: 0.0000e+00 - val_mae: 0.1436
# Epoch 41/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0450 - accuracy: 0.0000e+00 - mae: 0.1573 - val_loss: 0.0427 - val_accuracy: 0.0000e+00 - val_mae: 0.1454
# Epoch 42/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0429 - accuracy: 0.0000e+00 - mae: 0.1517 - val_loss: 0.0406 - val_accuracy: 0.0000e+00 - val_mae: 0.1391
# Epoch 43/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0421 - accuracy: 0.0000e+00 - mae: 0.1476 - val_loss: 0.0456 - val_accuracy: 0.0000e+00 - val_mae: 0.1528
# Epoch 44/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0422 - accuracy: 0.0000e+00 - mae: 0.1488 - val_loss: 0.0401 - val_accuracy: 0.0000e+00 - val_mae: 0.1437
# Epoch 45/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0425 - accuracy: 0.0000e+00 - mae: 0.1504 - val_loss: 0.0415 - val_accuracy: 0.0000e+00 - val_mae: 0.1441
# Epoch 46/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0438 - accuracy: 0.0000e+00 - mae: 0.1525 - val_loss: 0.0469 - val_accuracy: 0.0000e+00 - val_mae: 0.1672
# Epoch 47/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0425 - accuracy: 0.0000e+00 - mae: 0.1504 - val_loss: 0.0395 - val_accuracy: 0.0000e+00 - val_mae: 0.1390
# Epoch 48/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0429 - accuracy: 0.0000e+00 - mae: 0.1511 - val_loss: 0.0402 - val_accuracy: 0.0000e+00 - val_mae: 0.1404
# Epoch 49/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0427 - accuracy: 0.0000e+00 - mae: 0.1505 - val_loss: 0.0409 - val_accuracy: 0.0000e+00 - val_mae: 0.1362
# Epoch 50/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0438 - accuracy: 0.0000e+00 - mae: 0.1531 - val_loss: 0.0402 - val_accuracy: 0.0000e+00 - val_mae: 0.1398

# %%
# Plot the training and validation losses.
loss = history.history['loss']
val_loss = history.history['val_loss']
mae = history.history['mae']
val_mae = history.history['val_mae']

epochs = range(1, len(loss) + 1)

plt.figure()
plt.subplot(1, 2, 1)
plt.plot(epochs, loss, 'g.', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, mae, 'g.', label='Training MAE')
plt.plot(epochs, val_mae, 'b', label='Validation MAE')
plt.title('Training and validation MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()

#plt.tight_layout()

# %%
# Evaluate the model on Test set
loss = model2.evaluate(X_test, y_test)
predictions = model2.predict(X_test)

# Visualize the predictions against labels
plt.clf()
plt.title('Comparison of predictions with actual labels')
plt.plot(X_test, y_test, 'b.', label='Actual Labels (Ground Truth)')
plt.plot(X_test, predictions, 'r.', label='Predictions')
plt.legend()
plt.show()
# Out:
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0413 - accuracy: 0.0000e+00 - mae: 0.1433
# 63/63 [==============================] - 0s 842us/step

# %% [markdown]
# The deep model with two hidden layers (33 parameters) seems to give similar performance as the one with one hidden layer (49 parameters).

# %%
import os
MODEL_DIR = './models/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

# %%
model2.save('/content/gdrive/MyDrive/' + 'tfMdl')
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/tfMdl\assets

# %%
model2.save('/content/gdrive/MyDrive/' + 'tfMdl')

# Convert the model to the TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_keras_model(model2)
model_tflite = converter.convert()

# Save on disk
open(MODEL_DIR + 'model2.tflite', "wb").write(model_tflite)

# Quantize the model
def representative_dataset():
    for i in range(500):
        yield([X_train[i].reshape(1, 1)])
# Optimization level.
converter.optimizations = [tf.lite.Optimize.DEFAULT]
# Perform int8 quantization
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
#Setting the following input/output type requires the input/output to be quantized manually in the inference code.
#converter.inference_input_type = tf.int8
#converter.inference_output_type = tf.int8
# Representative dataset for
converter.representative_dataset = representative_dataset
model_tflite = converter.convert()

# Save the model to disk
open(MODEL_DIR + 'model2_q.tflite', "wb").write(model_tflite)
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/tfMdl\assets
# INFO:tensorflow:Assets written to: C:\Users\mbilal\AppData\Local\Temp\tmpm6ed4n29\assets
# INFO:tensorflow:Assets written to: C:\Users\mbilal\AppData\Local\Temp\tmp1p4zfv_t\assets
# INFO:tensorflow:Assets written to: C:\Users\mbilal\AppData\Local\Temp\tmp1p4zfv_t\assets
# c:\Users\mbilal\.conda\envs\tf-gpu\lib\site-packages\tensorflow\lite\python\convert.py:766: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# 2784

# %%
model_size = os.path.getsize(MODEL_DIR + 'model2.tflite')
print("Original model size is %d bytes" % model_size)
model_size_q = os.path.getsize(MODEL_DIR + 'model2_q.tflite')
print("Quantized model size is %d bytes" % model_size_q)
difference = model_size - model_size_q
print("You saved %d bytes!" % difference)
# Out:
# Original model size is 2264 bytes
# Quantized model size is 2784 bytes
# You saved -520 bytes!

# %%
# Instantiate an interpreter for each model
model = tf.lite.Interpreter(MODEL_DIR + 'model2.tflite')
model_q = tf.lite.Interpreter(MODEL_DIR + 'model2_q.tflite')

# Allocate memory for each model
model.allocate_tensors()
model_q.allocate_tensors()

# Get the input and output tensors so we can feed in values and get the results
model_input = model.tensor(model.get_input_details()[0]["index"])
model_output = model.tensor(model.get_output_details()[0]["index"])
model_q_input = model_q.tensor(model_q.get_input_details()[0]["index"])
model_q_output = model_q.tensor(model_q.get_output_details()[0]["index"])

# Create arrays to store the results
model_predictions = np.empty(X_test.size)
model_q_predictions = np.empty(X_test.size)

# Run each model's interpreter for each value and store the results in arrays
for i in range(X_test.size):
    model_input().fill(X_test[i])
    model.invoke()
    model_predictions[i] = model_output()[0]

    model_q_input().fill(X_test[i])
    model_q.invoke()
    model_q_predictions[i] = model_q_output()[0]

#error = model_predictions - model_q_predictions
# See how they line up with the data
plt.clf()
plt.title('Comparison of various models against actual values')
#plt.plot(X_test, y_test, 'bo', label='Actual values', alpha=0.4)
#plt.plot(X_test, predictions, 'ro', label='Original predictions')
plt.plot(X_test, model_predictions, 'bx', label='Lite predictions')
plt.plot(X_test, model_q_predictions, 'gx', label='Lite quantized predictions')
plt.legend()
plt.show()
# Out:
# C:\Users\mbilal\AppData\Local\Temp\ipykernel_18812\827773695.py:23: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   model_predictions[i] = model_output()[0]
# C:\Users\mbilal\AppData\Local\Temp\ipykernel_18812\827773695.py:27: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   model_q_predictions[i] = model_q_output()[0]

# %%
tf.lite.experimental.Analyzer.analyze(model_content=model_tflite)
# Out:
# === TFLite ModelAnalyzer ===
#
# Your TFLite model has '1' subgraph(s). In the subgraph description below,
# T# represents the Tensor numbers. For example, in Subgraph#0, the QUANTIZE op takes
# tensor #0 as input and produces tensor #7 as output.
#
# Subgraph#0 main(T#0) -> [T#11]
#   Op#0 QUANTIZE(T#0) -> [T#7]
#   Op#1 FULLY_CONNECTED(T#7, T#6[], T#5[-2217, -1080, -1499, -2342, -856, ...]) -> [T#8]
#   Op#2 FULLY_CONNECTED(T#8, T#4[], T#3[14648, -1646, -3267, -3511]) -> [T#9]
#   Op#3 FULLY_CONNECTED(T#9, T#2[], T#1[14087]) -> [T#10]
#   Op#4 DEQUANTIZE(T#10) -> [T#11]
#
# Tensors of Subgraph#0
#   T#0(serving_default_dense_2_input:0) shape_signature:[-1, 1], type:FLOAT32
#   T#1(sine_mlp_deep/dense_4/BiasAdd/ReadVariableOp) shape:[1], type:INT32 RO 4 bytes, data:[14087]
#   T#2(sine_mlp_deep/dense_4/MatMul) shape:[1, 4], type:INT8 RO 4 bytes, data:[]
#   T#3(sine_mlp_deep/dense_3/BiasAdd/ReadVariableOp) shape:[4], type:INT32 RO 16 bytes, data:[14648, -1646, -3267, -3511]
#   T#4(sine_mlp_deep/dense_3/MatMul) shape:[4, 12], type:INT8 RO 48 bytes, data:[]
#   T#5(sine_mlp_deep/dense_2/BiasAdd/ReadVariableOp) shape:[12], type:INT32 RO 48 bytes, data:[-2217, -1080, -1499, -2342, -856, ...]
#   T#6(sine_mlp_deep/dense_2/MatMul) shape:[12, 1], type:INT8 RO 12 bytes, data:[]
#   T#7(tfl.quantize) shape_signature:[-1, 1], type:INT8
#   T#8(sine_mlp_deep/dense_2/MatMul;sine_mlp_deep/dense_2/Relu;sine_mlp_deep/dense_2/BiasAdd) shape_signature:[-1, 12], type:INT8
#   T#9(sine_mlp_deep/dense_3/MatMul;sine_mlp_deep/dense_3/Relu;sine_mlp_deep/dense_3/BiasAdd) shape_signature:[-1, 4], type:INT8
#   T#10(StatefulPartitionedCall:01) shape_signature:[-1, 1], type:INT8
#   T#11(StatefulPartitionedCall:0) shape_signature:[-1, 1], type:FLOAT32
#
# ---------------------------------------------------------------
# Your TFLite model has '1' signature_def(s).
#
# Signature#0 key: 'serving_default'
# - Subgraph: Subgraph#0
# - Inputs:
#     'dense_2_input' : T#0
# - Outputs:
#     'dense_4' : T#11
#
# ---------------------------------------------------------------
#               Model size:       2784 bytes
#     Non-data buffer size:       2548 bytes (91.52 %)
#   Total data buffer size:        236 bytes (08.48 %)
#     (Zero value buffers):          0 bytes (00.00 %)
#
# * Buffers of TFLite model are mostly used for constant tensors.
#   And zero value buffers are buffers filled with zeros.
#   Non-data buffers area are used to store operators, subgraphs and etc.
#   You can find more details from https://github.com/tensorflow/tensorflow/blob/master/tensorflow/lite/schema/schema.fbs

# %%
# !xxd -i {MODEL_DIR + 'model2_q.tflite'} > {MODEL_DIR + 'model_q.cc'}
# !xxd -i {MODEL_DIR + 'model2.tflite'} > {MODEL_DIR + 'model.cc'}
# Out:
# 'xxd' is not recognized as an internal or external command,
# operable program or batch file.
# 'xxd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !cat {MODEL_DIR + 'model.cc'}
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.
